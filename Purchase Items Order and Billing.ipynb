# %%
import json

fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'115015001': {'Name': 'Helicopter',
#   'Type': 'Remote Control',
#   'Price': 699,
#   'Quantity': 1450,
#   'Color': 'Red'},
#  '115015002': {'Name': 'Turtle Car',
#   'Type': 'Remote Control',
#   'Price': 699,
#   'Quantity': 2189,
#   'Color': 'Green'},
#  '115015003': {'Name': 'Robot Car',
#   'Type': 'Remote Control',
#   'Price': 499,
#   'Quantity': 2700,
#   'Color': 'yellow'},
#  '115015004': {'Name': 'Unicorn Horse',
#   'Type': 'Soft Toy',
#   'Price': 299,
#   'Quantity': 2560,
#   'Color': 'Multicolor'},
#  '115015005': {'Name': 'Teddy Bear',
#   'Type': 'Soft Toy',
#   'Price': 419,
#   'Quantity': 1300,
#   'Color': 'Black-White'},
#  '115015006': {'Name': 'Fluflies Bear',
#   'Type': 'Soft Toy',
#   'Price': 216,
#   'Quantity': 1380,
#   'Color': 'Yellow'},
#  '115015007': {'Name': 'Mickey Chair',
#   'Type': 'Soft Toy',
#   'Price': 599,
#   'Quantity': 295,
#   'Color': 'Red'},
#  '115015008': {'Name': 'OZEE elephant',
#   'Type': 'Soft Toy',
#   'Price': 165,
#   'Quantity': 1170,
#   'Color': 'Pink'},
#  '115015009': {'Name': 'White Rabbit',
#   'Type': 'Soft Toy',
#   'Price': 119,
#   'Quantity': 1450,
#   'Color': 'White'},
#  '115015010': {'Name': 'Desti Elephant',
#   'Type': 'Soft Toy',
#   'Price': 156,
#   'Quantity': 1175,
#   'Color': 'Blue'},
#  '115015011': {'Name': 'Penguin',
#   'Type': 'Soft Toy',
#   'Price': 170,
#   'Quantity': 2500,
#   'Color': 'Blue'},
#  '115015012': {'Name': 'Catterpillar',
#   'Type': 'Soft Toy',
#   'Price': 160,
#   'Quantity': 1180,
#   'Color': 'Multicolor'},
#  '115015013': {'Name': 'Puzzle Mat',
#   'Type': 'Puzzle',
#   'Price': 189,
#   'Quantity': 1270,
#   'Color': 'Multicolor'},
#  '115015014': {'Name': 'Magic Cube',
#   'Type': 'Puzzle',
#   'Price': 149,
#   'Quantity': 1100,
#   'Color': 'Multicolor'},
#  '115015015': {'Name': 'Animal World',
#   'Type': 'Puzzle',
#   'Price': 244,
#   'Quantity': 2480,
#   'Color': 'Multicolor'},
#  '115015016': {'Name': 'Indian Map',
#   'Type': 'Puzzle',
#   'Price': 173,
#   'Quantity': 3240,
#   'Color': 'Multicolor'},
#  '115015017': {'Name': 'Marbles',
#   'Type': 'Marbles',
#   'Price': 199,
#   'Quantity': 2200,
#   'Color': 'Multicolor'},
#  '115015018': {'Name': 'Painting kit',
#   'Type': 'Education Toy',
#   'Price': 169,
#   'Quantity': 1600,
#   'Color': 'Multicolor'},
#  '115015019': {'Name': 'Makeup Set',
#   'Type': 'Girls Toy',
#   'Price': 189,
#   'Quantity': 510,
#   'Color': 'Multicolor'},
#  '115015020': {'Name': 'Kitchen Set',
#   'Type': 'Girls Toy',
#   'Price': 172,
#   'Quantity': 270,
#   'Color': 'Multicolor'},
#  '115015021': {'Name': 'Painting Brush',
#   'Type': 'Drawing Toy',
#   'Price': 72,
#   'Quantity': 2150,
#   'Color': 'Multicolor'},
#  '115015022': {'Name': 'Snake and ladder',
#   'Type': 'Board Game',
#   'Price': 779,
#   'Quantity': 4200,
#   'Color': 'Multicolor'},
#  '115015023': {'Name': 'Chess Set',
#   'Type': 'Board Game',
#   'Price': 347,
#   'Quantity': 2280,
#   'Color': 'Black-White'},
#  '115015024': {'Name': 'Business',
#   'Type': 'Board Game',
#   'Price': 265,
#   'Quantity': 1250,
#   'Color': 'Multicolor'},
#  '115015025': {'Name': 'Carrom',
#   'Type': 'Board Game',
#   'Price': 500,
#   'Quantity': 1720,
#   'Color': 'Shinny Cream'},
#  '115015026': {'Name': 'Tic Tac Toe',
#   'Type': 'Board Game',
#   'Price': 175,
#   'Quantity': 2020,
#   'Color': 'Yellow'},
#  '115015027': {'Name': 'Wodden DartBoard',
#   'Type': 'Board Game',
#   'Price': 499,
#   'Quantity': 3520,
#   'Color': 'Multicolor'},
#  '115015028': {'Name': 'Runner Scooter',
#   'Type': 'Outdoor',
#   'Price': 3299,
#   'Quantity': 3420,
#   'Color': 'Red'},
#  '115015029': {'Name': 'Beach Tool',
#   'Type': 'Outdoor',
#   'Price': 259,
#   'Quantity': 2002,
#   'Color': 'Multicolor'},
#  '115015030': {'Name': 'House Hut',
#   'Type': 'Play Hut',
#   'Price': 1565,
#   'Quantity': 2502,
#   'Color': 'Pink-White'},
#  '115015031': {'Name': 'Indian Currency Notes',
#   'Type': 'Prank Toy',
#   'Price': 170,
#   'Quantity': 350,
#   'Color': 'Multicolor'},
#  '115015032': {'Name': 'Spiderman Toy',
#   'Type': 'Action Toy',
#   'Price': 699,
#   'Quantity': 700,
#   'Color': 'Red-Blue'},
#  '115015033': {'Name': 'Rubber Snakes',
#   'Type': 'Action Toy',
#   'Price': 200,
#   'Quantity': 350,
#   'Color': 'Dark-Green'},
#  '115015034': {'Name': 'Spring Doll',
#   'Type': 'Action Toy',
#   'Price': 279,
#   'Quantity': 300,
#   'Color': 'Yellow'},
#  '115015035': {'Name': 'Piano Keyboard',
#   'Type': 'Musical Toy',
#   'Price': 499,
#   'Quantity': 400,
#   'Color': 'Black-White'},
#  '115015036': {'Name': 'Dancing Robot',
#   'Type': 'Action Toy',
#   'Price': 656,
#   'Quantity': 599,
#   'Color': 'Grey'},
#  '115015037': {'Name': 'Racket Set',
#   'Type': 'Outdoor Toy',
#   'Price': 159,
#   'Quantity': 340,
#   'Color': 'Blue'},
#  '115015038': {'Name': 'Ball & Stumps',
#   'Type': 'Outdoor Toy',
#   'Price': 340,
#   'Quantity': 140,
#   'Color': 'Yellow'},
#  '115015039': {'Name': 'Punching Bag',
#   'Type': 'Outdoor Toy',
#   'Price': 599,
#   'Quantity': 140,
#   'Color': 'Red'},
#  '115015040': {'Name': 'Football',
#   'Type': 'Outdoor Toy',
#   'Price': 299,
#   'Quantity': 1198,
#   'Color': 'Black-White'}}

# %% [markdown]
# ### After Choosing Choice Number
# #### 1. Item Purchase

# %%
import json
import time
import datetime

a_name=input("Please enter your name: ")
print(f"Hello {a_name} ! Welcome to our Shopping Store. Buy Products at Discounted & Cheapest Rate !!")


print("********************************************************************************************")

print(f"--------------------WELCOME {a_name}  TO THE TOY SHOP -------------------------------------")

print("*******************************************************************************************")



    
def exit():
    pass

def itemPurchase():
    with open ("record.json","r") as fd:
        r = fd.read()
        records = json.loads(r)
    print("Loading items ... Please Wait !!!")
    time.sleep(3)
    print(f"Items Available at Our Stores are {records} ")
    bill = 0
    i = 0
    num_items = 100
    ls_items = []
    while(num_items > 0):
        print("========================================================================================")
        item = input("Enter one item that you wish to Purchase: ")
        x = item.capitalize()
        quan = int(input("Enter the quantity of Product: "))
        print("Product: ", records[x]['Name'])
        print("Price: ", records[x]['Price'])
        print("Billing Amount: ", records[x]['Price'] * quan)
        if(x in records):
            bill = bill + records[x]['Price'] * quan
            ls_items.append(x)
            num_items += 1
            i += 1
            records[x]["Quantity"] = records[x]["Quantity"] - quan
        else:
            print("________________________________________________________________________________________")
            print("We Dont Have This Item as of Now. ")
            print("_________________________________________________________________________________________")
        wish = input("Do You Wish To enter another item y/n : ")
        if(wish == "y"):
            continue
        else:
            break


    # Discount
    if (bill <= 5000):
        disc = 5.0
        discount = (disc*bill)/100
        total=float(bill-discount)
    elif (bill >= 5000):
        disc = 10.0
        discount = (disc*bill)/100
        total=float(bill-discount)
    
    # Bill
    print("******************************************************************************************")  
    print("                        "+  "  Happy Toy Zone "                            + "           ") 
    print("               " +"Toy shop is a place where kids love to go"           +  "            ")
    print("                 "  + "It is a place where toys are sold. "              +  "     "       )
    print("******************************************************************************************")
    print("_____________________________________________________________________________________________") 
    print('                                                                                         ')
    print(f"Customer Name : {a_name}                         Time & Date of Shopping : {time.ctime()}")
    print("______________________________________________________________________________________________")
    time.sleep(2)
    print("                                                                                          ")
    print(f"                Bill Amount is {bill} for the Toys you have purchased.  ")
    print("                                                                                         ")
    print(f"            Discount {disc}% discount and Your Payable Amount is: {total}")
    print('                                                                                           ')
    print("^^^^^^^^^^^^^^^^^^^^^ Pay your Bill on Cash Counter ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
    print( "                                                                                            ")
    
    

print("Please Choose from the Below Option : ")

print("1. Item Purchase : ")
print("2. Exit : ")

choice = int(input("Enter Your Choice Here : "))
print("OK .. Wait For The Next Step ... ")
time.sleep(3)

if (choice == 1):    
    itemPurchase()

elif (choice == 2):
    exit()
    




print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
print("                  " + "THANK YOU FOR SHOPPING WITH US" +          "             "          )
print("                      "  +  "Visit Again" +         "                                     ")
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
# Out:
# Please enter your name: Shaurya Singh
# Hello Shaurya Singh ! Welcome to our Shopping Store. Buy Products at Discounted & Cheapest Rate !!
# ********************************************************************************************
# --------------------WELCOME Shaurya Singh  TO THE TOY SHOP -------------------------------------
# *******************************************************************************************
# Please Choose from the Below Option :
# 1. Item Purchase :
# 2. Exit :
# Enter Your Choice Here : 1
# OK .. Wait For The Next Step ...
# Loading items ... Please Wait !!!
# Items Available at Our Stores are {'115015001': {'Name': 'Helicopter', 'Type': 'Remote Control', 'Price': 699, 'Quantity': 1450, 'Color': 'Red'}, '115015002': {'Name': 'Turtle Car', 'Type': 'Remote Control', 'Price': 699, 'Quantity': 2189, 'Color': 'Green'}, '115015003': {'Name': 'Robot Car', 'Type': 'Remote Control', 'Price': 499, 'Quantity': 2700, 'Color': 'yellow'}, '115015004': {'Name': 'Unicorn Horse', 'Type': 'Soft Toy', 'Price': 299, 'Quantity': 2560, 'Color': 'Multicolor'}, '115015005': {'Name': 'Teddy Bear', 'Type': 'Soft Toy', 'Price': 419, 'Quantity': 1300, 'Color': 'Black-White'}, '115015006': {'Name': 'Fluflies Bear', 'Type': 'Soft Toy', 'Price': 216, 'Quantity': 1380, 'Color': 'Yellow'}, '115015007': {'Name': 'Mickey Chair', 'Type': 'Soft Toy', 'Price': 599, 'Quantity': 295, 'Color': 'Red'}, '115015008': {'Name': 'OZEE elephant', 'Type': 'Soft Toy', 'Price': 165, 'Quantity': 1170, 'Color': 'Pink'}, '115015009': {'Name': 'White Rabbit', 'Type': 'Soft Toy', 'Price': 119, 'Quantity': 1450, 'Color': 'White'}, '115015010': {'Name': 'Desti Elephant', 'Type': 'Soft Toy', 'Price': 156, 'Quantity': 1175, 'Color': 'Blue'}, '115015011': {'Name': 'Penguin', 'Type': 'Soft Toy', 'Price': 170, 'Quantity': 2500, 'Color': 'Blue'}, '115015012': {'Name': 'Catterpillar', 'Type': 'Soft Toy', 'Price': 160, 'Quantity': 1180, 'Color': 'Multicolor'}, '115015013': {'Name': 'Puzzle Mat', 'Type': 'Puzzle', 'Price': 189, 'Quantity': 1270, 'Color': 'Multicolor'}, '115015014': {'Name': 'Magic Cube', 'Type': 'Puzzle', 'Price': 149, 'Quantity': 1100, 'Color': 'Multicolor'}, '115015015': {'Name': 'Animal World', 'Type': 'Puzzle', 'Price': 244, 'Quantity': 2480, 'Color': 'Multicolor'}, '115015016': {'Name': 'Indian Map', 'Type': 'Puzzle', 'Price': 173, 'Quantity': 3240, 'Color': 'Multicolor'}, '115015017': {'Name': 'Marbles', 'Type': 'Marbles', 'Price': 199, 'Quantity': 2200, 'Color': 'Multicolor'}, '115015018': {'Name': 'Painting kit', 'Type': 'Education Toy', 'Price': 169, 'Quantity': 1600, 'Color': 'Multicolor'}, '115015019': {'Name': 'Makeup Set', 'Type': 'Girls Toy', 'Price': 189, 'Quantity': 510, 'Color': 'Multicolor'}, '115015020': {'Name': 'Kitchen Set', 'Type': 'Girls Toy', 'Price': 172, 'Quantity': 270, 'Color': 'Multicolor'}, '115015021': {'Name': 'Painting Brush', 'Type': 'Drawing Toy', 'Price': 72, 'Quantity': 2150, 'Color': 'Multicolor'}, '115015022': {'Name': 'Snake and ladder', 'Type': 'Board Game', 'Price': 779, 'Quantity': 4200, 'Color': 'Multicolor'}, '115015023': {'Name': 'Chess Set', 'Type': 'Board Game', 'Price': 347, 'Quantity': 2280, 'Color': 'Black-White'}, '115015024': {'Name': 'Business', 'Type': 'Board Game', 'Price': 265, 'Quantity': 1250, 'Color': 'Multicolor'}, '115015025': {'Name': 'Carrom', 'Type': 'Board Game', 'Price': 500, 'Quantity': 1720, 'Color': 'Shinny Cream'}, '115015026': {'Name': 'Tic Tac Toe', 'Type': 'Board Game', 'Price': 175, 'Quantity': 2020, 'Color': 'Yellow'}, '115015027': {'Name': 'Wodden DartBoard', 'Type': 'Board Game', 'Price': 499, 'Quantity': 3520, 'Color': 'Multicolor'}, '115015028': {'Name': 'Runner Scooter', 'Type': 'Outdoor', 'Price': 3299, 'Quantity': 3420, 'Color': 'Red'}, '115015029': {'Name': 'Beach Tool', 'Type': 'Outdoor', 'Price': 259, 'Quantity': 2002, 'Color': 'Multicolor'}, '115015030': {'Name': 'House Hut', 'Type': 'Play Hut', 'Price': 1565, 'Quantity': 2502, 'Color': 'Pink-White'}, '115015031': {'Name': 'Indian Currency Notes', 'Type': 'Prank Toy', 'Price': 170, 'Quantity': 350, 'Color': 'Multicolor'}, '115015032': {'Name': 'Spiderman Toy', 'Type': 'Action Toy', 'Price': 699, 'Quantity': 700, 'Color': 'Red-Blue'}, '115015033': {'Name': 'Rubber Snakes', 'Type': 'Action Toy', 'Price': 200, 'Quantity': 350, 'Color': 'Dark-Green'}, '115015034': {'Name': 'Spring Doll', 'Type': 'Action Toy', 'Price': 279, 'Quantity': 300, 'Color': 'Yellow'}, '115015035': {'Name': 'Piano Keyboard', 'Type': 'Musical Toy', 'Price': 499, 'Quantity': 400, 'Color': 'Black-White'}, '115015036': {'Name': ' ...
# ========================================================================================
# Enter one item that you wish to Purchase: 115015009
# Enter the quantity of Product: 10
# Product:  White Rabbit
# Price:  119
# Billing Amount:  1190
# Do You Wish To enter another item y/n : y
# ========================================================================================
# Enter one item that you wish to Purchase: 115015020
# Enter the quantity of Product: 10
# Product:  Kitchen Set
# Price:  172
# Billing Amount:  1720
# Do You Wish To enter another item y/n : y
# ========================================================================================
# Enter one item that you wish to Purchase: 115015024
# Enter the quantity of Product: 5
# Product:  Business
# Price:  265
# Billing Amount:  1325
# Do You Wish To enter another item y/n : y
# ========================================================================================
# Enter one item that you wish to Purchase: 115015035
# Enter the quantity of Product: 15
# Product:  Piano Keyboard
# Price:  499
# Billing Amount:  7485
# Do You Wish To enter another item y/n : n
# ******************************************************************************************
#                           Happy Toy Zone
#                Toy shop is a place where kids love to go
#                  It is a place where toys are sold.
# ******************************************************************************************
# _____________________________________________________________________________________________
#
# Customer Name : Shaurya Singh                         Time & Date of Shopping : Sun Sep  5 20:39:09 2021
# ______________________________________________________________________________________________
#
#                 Bill Amount is 11720 for the Toys you have purchased.
#
#             Discount 10.0% discount and Your Payable Amount is: 10548.0
#
# ^^^^^^^^^^^^^^^^^^^^^ Pay your Bill on Cash Counter ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   THANK YOU FOR SHOPPING WITH US
#                       Visit Again
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %% [markdown]
# ### After Choosing Choice Number 2
# #### 2. Exit

# %%
import json
import time
import datetime

a_name=input("Please enter your name: ")
print(f"Hello {a_name} ! Welcome to our Shopping Store. Buy Products at Discounted & Cheapest Rate !!")


print("********************************************************************************************")

print(f"--------------------WELCOME {a_name}  TO THE TOY SHOP -------------------------------------")

print("*******************************************************************************************")



    
def exit():
    pass

def itemPurchase():
    with open ("record.json","r") as fd:
        r = fd.read()
        records = json.loads(r)
    print("Loading items ... Please Wait !!!")
    time.sleep(3)
    print(f"Items Available at Our Stores are {records} ")
    bill = 0
    i = 0
    num_items = 100
    ls_items = []
    while(num_items > 0):
        print("========================================================================================")
        item = input("Enter one item that you wish to Purchase: ")
        x = item.capitalize()
        quan = int(input("Enter the quantity of Product: "))
        print("Product: ", records[x]['Name'])
        print("Price: ", records[x]['Price'])
        print("Billing Amount: ", records[x]['Price'] * quan)
        if(x in records):
            bill = bill + records[x]['Price'] * quan
            ls_items.append(x)
            num_items += 1
            i += 1
            records[x]["Quantity"] = records[x]["Quantity"] - quan
        else:
            print("________________________________________________________________________________________")
            print("We Dont Have This Item as of Now. ")
            print("_________________________________________________________________________________________")
        wish = input("Do You Wish To enter another item y/n : ")
        if(wish == "y"):
            continue
        else:
            break


    # Discount
    if (bill <= 500):
        disc = 5.0
        discount = (disc*bill)/100
        total=float(bill-discount)
    elif (bill >= 500):
        disc = 10.0
        discount = (disc*bill)/100
        total=float(bill-discount)
    
    # Bill
    print("******************************************************************************************")  
    print("                        "+  "  Happy Toy Zone "                            + "           ") 
    print("               " +"Toy shop is a place where kids love to go"           +  "            ")
    print("                 "  + "It is a place where toys are sold. "              +  "     "       )
    print("******************************************************************************************")
    print("_____________________________________________________________________________________________") 
    print('                                                                                         ')
    print(f"Customer Name : {a_name}                         Time & Date of Shopping : {time.ctime()}")
    print("______________________________________________________________________________________________")
    time.sleep(2)
    print("                                                                                          ")
    print(f"                Bill Amount is {bill} for the Toys you have purchased.  ")
    print("                                                                                         ")
    print(f"            Discount {disc}% discount and Your Payable Amount is: {total}")
    print('                                                                                           ')
    print("^^^^^^^^^^^^^^^^^^^^^ Pay your Bill on Cash Counter ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
    print( "                                                                                            ")
    
    

print("Please Choose from the Below Option : ")

print("1. Item Purchase : ")
print("2. Exit : ")

choice = int(input("Enter Your Choice Here : "))
print("OK .. Wait For The Next Step ... ")
time.sleep(3)

if (choice == 1):    
    itemPurchase()

elif (choice == 2):
    exit()
    




print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
print("                  " + "THANK YOU FOR VISITING US" +          "             "          )
print("                      "  +  "Visit Again" +         "                                     ")
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
# Out:
# Please enter your name: Aayushi Rai
# Hello Aayushi Rai ! Welcome to our Shopping Store. Buy Products at Discounted & Cheapest Rate !!
# ********************************************************************************************
# --------------------WELCOME Aayushi Rai  TO THE TOY SHOP -------------------------------------
# *******************************************************************************************
# Please Choose from the Below Option :
# 1. Item Purchase :
# 2. Exit :
# Enter Your Choice Here : 2
# OK .. Wait For The Next Step ...
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                   THANK YOU FOR VISITING US
#                       Visit Again
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
